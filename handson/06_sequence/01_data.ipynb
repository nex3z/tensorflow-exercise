# %%
import numpy as np
import utils

# %%
(x_train, y_train), (x_val, y_val), (x_test, y_test) = utils.load_time_series_data()
print(f"x_train.shape = {x_train.shape}, y_train.shape = {y_train.shape}")
print(f"x_val.shape = {x_val.shape}, y_val.shape = {y_val.shape}")
print(f"x_test.shape = {x_test.shape}, y_test.shape = {y_test.shape}")
# Out:
# x_train.shape = (7000, 50), y_train.shape = (7000,)
# x_val.shape = (2000, 50), y_val.shape = (2000,)
# x_test.shape = (1000, 50), y_test.shape = (1000,)

# %%
utils.plot_series(x_val[0], y_val[0])

# %% [markdown]
# ## Naive

# %%
y_pred = x_val[:, -1]

# %%
utils.plot_series(x_val[0], y_val[0], y_pred[0])

# %%
utils.evaluate(y_val, y_pred)
# Out:
# mse = 0.02021137, mae = 0.11627829
