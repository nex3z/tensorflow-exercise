# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

import utils

# %%
RANDOM_SEED = 42

# %%
(x_train, y_train), (x_val, y_val), (x_test, y_test) = utils.load_housing_data()
print(f"x_train.shape = {x_train.shape}, y_train.shape = {y_train.shape}")
print(f"x_val.shape = {x_val.shape}, y_val.shape = {y_val.shape}")
print(f"x_test.shape = {x_test.shape}, y_test.shape = {y_test.shape}")
# Out:
# x_train.shape = (11610, 8), y_train.shape = (11610,)
# x_val.shape = (3870, 8), y_val.shape = (3870,)
# x_test.shape = (5160, 8), y_test.shape = (5160,)

# %% [markdown]
# ## Sequential

# %%
utils.reset_session(RANDOM_SEED)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation='relu', input_shape=x_train.shape[1:]),
    keras.layers.Dense(1)
])
model.summary()

model.compile(optimizer=keras.optimizers.SGD(lr=1e-3), loss='mse')

history = model.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                270
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 363/363 [==============================] - 0s 1ms/step - loss: 1.6419 - val_loss: 0.8560
# Epoch 2/20
# 363/363 [==============================] - 0s 948us/step - loss: 0.7047 - val_loss: 0.6531
# Epoch 3/20
# 363/363 [==============================] - 0s 952us/step - loss: 0.6345 - val_loss: 0.6099
# Epoch 4/20
# 363/363 [==============================] - 0s 976us/step - loss: 0.5977 - val_loss: 0.5658
# Epoch 5/20
# 363/363 [==============================] - 0s 933us/step - loss: 0.5706 - val_loss: 0.5355
# Epoch 6/20
# 363/363 [==============================] - 0s 932us/step - loss: 0.5472 - val_loss: 0.5173
# Epoch 7/20
# 363/363 [==============================] - 0s 999us/step - loss: 0.5288 - val_loss: 0.5081
# Epoch 8/20
# 363/363 [==============================] - 0s 954us/step - loss: 0.5130 - val_loss: 0.4799
# Epoch 9/20
# 363/363 [==============================] - 0s 929us/step - loss: 0.4992 - val_loss: 0.4690
# Epoch 10/20
# 363/363 [==============================] - 0s 946us/step - loss: 0.4875 - val_loss: 0.4656
# Epoch 11/20
# 363/363 [==============================] - 0s 991us/step - loss: 0.4777 - val_loss: 0.4482
# Epoch 12/20
# 363/363 [==============================] - 0s 939us/step - loss: 0.4688 - val_loss: 0.4479
# Epoch 13/20
# 363/363 [==============================] - 0s 967us/step - loss: 0.4615 - val_loss: 0.4296
# Epoch 14/20
# 363/363 [==============================] - 0s 978us/step - loss: 0.4547 - val_loss: 0.4233
# Epoch 15/20
# 363/363 [==============================] - 0s 946us/step - loss: 0.4488 - val_loss: 0.4176
# Epoch 16/20
# 363/363 [==============================] - 0s 974us/step - loss: 0.4435 - val_loss: 0.4123
# Epoch 17/20
# 363/363 [==============================] - 0s 949us/step - loss: 0.4389 - val_loss: 0.4071
# Epoch 18/20
# 363/363 [==============================] - 0s 944us/step - loss: 0.4347 - val_loss: 0.4037
# Epoch 19/20
# 363/363 [==============================] - 0s 975us/step - loss: 0.4306 - val_loss: 0.4000
# Epoch 20/20
# 363/363 [==============================] - 0s 869us/step - loss: 0.4273 - val_loss: 0.3969

# %%
model.predict(x_test[:3])
# Out:
# array([[0.38856646],
#        [1.6792021 ],
#        [3.1022794 ]], dtype=float32)

# %% [markdown]
# ## Functional

# %%
utils.reset_session(RANDOM_SEED)

# %%
input_layer = keras.layers.Input(shape=x_train.shape[1:])
x = keras.layers.Dense(30, activation='relu')(input_layer)
output_layer = keras.layers.Dense(1)(x)

model = keras.models.Model(inputs=[input_layer], outputs=[output_layer])
model.summary()

model.compile(optimizer=keras.optimizers.SGD(lr=1e-3), loss='mse')

history = model.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val))
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# dense (Dense)                (None, 30)                270
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 363/363 [==============================] - 0s 1ms/step - loss: 1.6419 - val_loss: 0.8560
# Epoch 2/20
# 363/363 [==============================] - 0s 968us/step - loss: 0.7047 - val_loss: 0.6531
# Epoch 3/20
# 363/363 [==============================] - 0s 970us/step - loss: 0.6345 - val_loss: 0.6099
# Epoch 4/20
# 363/363 [==============================] - 0s 947us/step - loss: 0.5977 - val_loss: 0.5658
# Epoch 5/20
# 363/363 [==============================] - 0s 941us/step - loss: 0.5706 - val_loss: 0.5355
# Epoch 6/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.5472 - val_loss: 0.5173
# Epoch 7/20
# 363/363 [==============================] - 0s 983us/step - loss: 0.5288 - val_loss: 0.5081
# Epoch 8/20
# 363/363 [==============================] - 0s 962us/step - loss: 0.5130 - val_loss: 0.4799
# Epoch 9/20
# 363/363 [==============================] - 0s 958us/step - loss: 0.4992 - val_loss: 0.4690
# Epoch 10/20
# 363/363 [==============================] - 0s 982us/step - loss: 0.4875 - val_loss: 0.4656
# Epoch 11/20
# 363/363 [==============================] - 0s 950us/step - loss: 0.4777 - val_loss: 0.4482
# Epoch 12/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4688 - val_loss: 0.4479
# Epoch 13/20
# 363/363 [==============================] - 0s 940us/step - loss: 0.4615 - val_loss: 0.4296
# Epoch 14/20
# 363/363 [==============================] - 0s 911us/step - loss: 0.4547 - val_loss: 0.4233
# Epoch 15/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4488 - val_loss: 0.4176
# Epoch 16/20
# 363/363 [==============================] - 0s 965us/step - loss: 0.4435 - val_loss: 0.4123
# Epoch 17/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4389 - val_loss: 0.4071
# Epoch 18/20
# 363/363 [==============================] - 0s 919us/step - loss: 0.4347 - val_loss: 0.4037
# Epoch 19/20
# 363/363 [==============================] - 0s 957us/step - loss: 0.4306 - val_loss: 0.4000
# Epoch 20/20
# 363/363 [==============================] - 0s 981us/step - loss: 0.4273 - val_loss: 0.3969

# %%
model.predict(x_test[:3])
# Out:
# array([[0.38856646],
#        [1.6792021 ],
#        [3.1022794 ]], dtype=float32)
